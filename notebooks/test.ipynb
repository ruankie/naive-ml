# %%
import numpy as np
import pandas as pd
from src import utilities

# %%
data = np.random.normal(loc=0.0, scale=1.0, size=(25,))
df = pd.Series(data)
df.head()
# Out:
# 0   -1.923875
# 1    1.970564
# 2    0.479685
# 3   -0.919646
# 4    0.320931
# dtype: float64

# %%
df.plot(figsize=(14,4))
# Out:
# <AxesSubplot:>

# %%
utilities.say_hello()
# Out:
# hello world

# %%
utilities.get_int()
# Out:
# 3
